# %%
import pandas as pd

TRAIN_22_DATA_PATH = './datasets/WASSA22_train.tsv'
DEV_22_DATA_PATH = './datasets/WASSA22_dev.tsv'
DEV_22_GOLD_PATH = './datasets/goldstandard_dev_2022.tsv'

train_22_df = pd.read_csv(TRAIN_22_DATA_PATH, sep='\t')

dev_22_df = pd.read_csv(DEV_22_DATA_PATH, sep='\t')
dev_22_gold = pd.read_csv(DEV_22_GOLD_PATH, header=None, usecols=[2], names=['emotion'], sep='\t')
dev_22_df = dev_22_df.merge(dev_22_gold, left_index=True, right_index=True, how='outer')

essay_22_df = pd.concat([train_22_df[['message_id', 'essay', 'emotion']], dev_22_df[['message_id', 'essay', 'emotion']]])


DATA2023_PATH = "./datasets/train_essay_level_preproc.tsv"
train2023_df = pd.read_csv(DATA2023_PATH, sep='\t')

# %%
essay_22_df
# Out:
#               message_id                                              essay  \
# 0    R_1hGrPtWM4SumG0U_1  it is really diheartening to read about these ...
# 1    R_1hGrPtWM4SumG0U_2  the phone lines from the suicide prevention li...
# 2    R_1hGrPtWM4SumG0U_3  no matter what your heritage, you should be ab...
# 3    R_1hGrPtWM4SumG0U_4  it is frightening to learn about all these sha...
# 4    R_1hGrPtWM4SumG0U_5  the eldest generation of russians aren't being...
# ..                   ...                                                ...
# 265  R_r3CoQ7YjIwxVvJT_1  While I feel bad for the arrest charges, I don...
# 266  R_r3CoQ7YjIwxVvJT_2  This is such a tragedy.  All I can think about...
# 267  R_r3CoQ7YjIwxVvJT_3  I'm still on the fence regarding climate chang...
# 268  R_r3CoQ7YjIwxVvJT_4  I can understand why the Jewish community woul...
# 269  R_r3CoQ7YjIwxVvJT_5  As a woman, it is very discouraging to see tha...
#
#      emotion
# 0    sadness
# 1    sadness
# 2    neutral
# 3       fear
# 4    sadness
# ..       ...
# 265    anger
# 266     fear
# 267  neutral
# 268      joy
# 269  sadness
#
# [2130 rows x 3 columns]

# %%
class_count = train2021_df['emotion'].value_counts()
class_count
# Out:
# sadness     647
# anger       349
# neutral     275
# fear        194
# surprise    164
# disgust     149
# joy          82
# Name: emotion, dtype: int64

# %%
HOPE_PATH = './datasetS/english_hope.csv'
hope_df = pd.read_csv(HOPE_PATH, sep="\t")

essay_22_df = pd.concat([essay_22_df [['essay', 'emotion']], hope_df[['essay', 'emotion']]])
essay_22_df
# Out:
#                                                 essay  emotion
# 0   it is really diheartening to read about these ...  sadness
# 1   the phone lines from the suicide prevention li...  sadness
# 2   no matter what your heritage, you should be ab...  neutral
# 3   it is frightening to learn about all these sha...     fear
# 4   the eldest generation of russians aren't being...  sadness
# ..                                                ...      ...
# 49  Her eyes are so beautiful. Very striking. You ...     hope
# 50  It’s a fact but it’s not the case at this time...     hope
# 51  Blue Lives Matter. Black Lives Matter. Hispani...     hope
# 52  I dont understand why it is up to anyone else ...     hope
# 53  Being pro-life and pro-sterilization is not hy...     hope
#
# [2292 rows x 2 columns]

# %%
essay_22_df = essay_22_df.sample(frac=1).reset_index(drop=True)
essay_22_df
# Out:
#                                                   essay  emotion
# 0     i just read an article about a father who kill...  sadness
# 1     It’s a shame that Nevada is going through this...  sadness
# 2     You have to read this.  It's unbelievable that...    anger
# 3     I can understand being absent minded and conce...  sadness
# 4     Did you hear about what had happened to the ki...  sadness
# ...                                                 ...      ...
# 2287  SO I just read an article about goldfish. You ...     fear
# 2288  It aggravates me that in our modern society le...    anger
# 2289  I feel so bad for that innocent customer. This...     fear
# 2290  It’s racist to say black lives matter it’s cor...     hope
# 2291  Wow that dude has a lot of money! More power t...      joy
#
# [2292 rows x 2 columns]

# %%
DATA_PATH = './datasets/train_essay_level_additional.csv'
essay_22_df.to_csv(DATA_PATH, index=False, sep='\t')
